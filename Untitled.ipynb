# %%
from allennlp.commands.elmo import ElmoEmbedder

# %%
elmo = ElmoEmbedder()
# Out:
# ...
# 100%|██████████| 374434792/374434792 [00:37<00:00, 9999952.85B/s]

# %%
elmo.embed_sentence(['i', 'am', 'groot'])[2]
# Out:
# array([[-2.4030967 , -1.1643391 , -0.6898723 , ..., -0.33473057,
#          1.1179944 ,  0.33556533],
#        [-0.6635145 , -1.3817227 , -1.0413442 , ...,  0.24911949,
#          1.5477575 ,  0.26102725],
#        [ 0.07834392, -1.7417295 ,  0.59330213, ...,  0.46589282,
#          0.8613267 ,  0.09742086]], dtype=float32)

# %%
elmo.embed_sentence(['i', 'am', 'good'])[2]
# Out:
# array([[-2.4290223 , -1.1500251 , -0.73029524, ..., -0.3947934 ,
#          0.61468095,  0.44682503],
#        [-0.704553  , -1.3447716 , -1.0360435 , ...,  0.47456047,
#          1.3105927 ,  0.82714736],
#        [ 0.8715906 , -1.608118  ,  0.42005223, ...,  0.19085877,
#          0.5661574 ,  0.12130754]], dtype=float32)

# %%
elmo.embed_sentence(['not', 'good'])[2]
# Out:
# array([[-0.1613689 , -0.5450244 ,  0.54333633, ...,  0.8268775 ,
#          0.34238994,  0.18726964],
#        [ 0.9123662 , -0.3741244 ,  1.1757708 , ...,  0.18351164,
#          0.5698827 ,  0.1120892 ]], dtype=float32)

# %%
from bert_embedding import BertEmbedding

bert_embedding = BertEmbedding()

# result = bert_embedding(words)

# words_embeddings = {}
# for i in result:
#     words_embeddings[i[0][0]] = i[1][0]

# %%
bert_embedding(['i', 'will', 'not', 'abandon', 'you'])[3][1][0].sum()
# Out:
# -7.3738537

# %%
bert_embedding(['i', 'am', 'good'])
# Out:
# [(['i'],
#   [array([-3.25331599e-01, -3.46561611e-01,  4.29405212e-01, -3.96290034e-01,
#            3.92348021e-02,  4.31209169e-02,  2.62787372e-01,  4.49371010e-01,
#            8.42511803e-02, -7.80547619e-01, -7.68595338e-01,  1.82808898e-02,
#            3.30514342e-01,  2.11116731e-01,  3.89601924e-02, -1.04872912e-01,
#            6.49706542e-01,  3.01850110e-01, -8.97732675e-02,  6.37651980e-01,
#            1.63249075e-02,  4.21480149e-01, -3.30491155e-01,  1.85020477e-01,
#           -2.07559392e-02,  9.22393858e-01, -5.38871765e-01, -4.52164441e-01,
#           -4.51066047e-01,  4.11571294e-01, -4.00682017e-02,  9.40975994e-02,
#            4.08912599e-01,  3.52807462e-01, -5.01864612e-01, -5.43319404e-01,
#           -1.77644752e-02,  1.02241397e-01, -6.06602311e-01, -2.47278795e-01,
#            3.00695777e-01, -4.47480708e-01,  4.15057898e-01, -7.98903346e-01,
#           -6.15273975e-02,  4.00952101e-01,  3.41679394e-01, -2.42737457e-01,
# ...

# %%
bert_embedding(['not', 'good'])
# Out:
# [(['not'],
#   [array([ 3.35192010e-02, -4.65922982e-01, -9.44609940e-02, -2.00552508e-01,
#           -5.27994446e-02, -3.90778244e-01, -2.90525198e-01,  6.11261487e-01,
#           -4.19834629e-04, -7.58674979e-01, -7.09497631e-01, -1.23040505e-01,
#            2.98110008e-01,  9.15698633e-02, -1.40255004e-01,  1.94044620e-01,
#            6.90274060e-01, -1.52190879e-01,  3.53941441e-01,  8.84200990e-01,
#           -5.10519028e-01, -4.16920371e-02, -2.58348435e-01,  2.71837085e-01,
#            1.30116254e-01,  4.01673675e-01, -4.04259294e-01, -2.76569366e-01,
#            2.17162073e-01,  6.42590284e-01,  1.61853179e-01, -5.79591841e-03,
#           -1.73988819e-01, -3.87804657e-01, -8.56229663e-01, -3.66983831e-01,
#           -1.94980517e-01,  4.95620728e-01, -6.57535136e-01, -2.11387351e-01,
#            2.34298661e-01, -5.51206172e-01,  6.66491330e-01, -2.09418714e-01,
#            1.76452965e-01,  4.11761105e-01,  1.11014700e+00,  3.37407691e-05,
# ...

# %%
# bert_embedding = BertEmbedding()

# result = bert_embedding(words)

# words_embeddings = {}
# for i in result:
#     words_embeddings[i[0][0]] = i[1][0]
